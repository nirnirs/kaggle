# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.dummy import DummyClassifier
from sklearn import svm
from sklearn.metrics import log_loss

# %%
data = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
data
# Out:
#       Activity        D1        D2    D3    D4        D5        D6        D7  \
# 0            1  0.000000  0.497009  0.10  0.00  0.132956  0.678031  0.273166
# 1            1  0.366667  0.606291  0.05  0.00  0.111209  0.803455  0.106105
# 2            1  0.033300  0.480124  0.00  0.00  0.209791  0.610350  0.356453
# 3            1  0.000000  0.538825  0.00  0.50  0.196344  0.724230  0.235606
# 4            0  0.100000  0.517794  0.00  0.00  0.494734  0.781422  0.154361
# 5            0  0.133333  0.771035  0.20  0.25  0.122153  0.677398  0.267224
# 6            1  0.066700  0.567401  0.10  0.00  0.116578  0.689802  0.274886
# 7            1  0.133333  0.610057  0.15  0.00  0.105176  0.759602  0.313393
# 8            1  0.000000  0.776816  0.05  0.00  0.458446  0.738631  0.246347
# 9            0  0.100000  0.768150  0.10  0.25  0.262299  0.598972  0.377065
# 10           1  0.000000  0.660210  0.00  0.00  0.383456  0.720737  0.222087
# ...

# %%
X = data[data.columns[1:]]
y = data.Activity

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Dummy

# %%
dummy = DummyClassifier("uniform")

# %%
-cross_val_score(dummy, train_X, train_y, scoring='neg_log_loss').mean()
# Out:
# 0.69314718055994529

# %% [markdown]
# # Logistic Regression

# %%
logistic = LogisticRegression()

# %%
-cross_val_score(logistic, train_X, train_y, scoring='neg_log_loss').mean()
# Out:
# 0.66591445845469577

# %% [markdown]
# # SVM

# %%
svc = svm.SVC(probability=True)

# %%
-cross_val_score(svc, train_X, train_y, scoring='neg_log_loss').mean()

# %%
svc.fit(X,y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svc.classes_
# Out:
# array([0, 1])

# %%
svc_prediction = svc.predict_proba(test)

# %%
svc_results = pd.DataFrame(svc_prediction[:,1], columns=['PredictedProbability'], index=test.index)

# %%
svc_results.index += 1 # kaggle expects indexing to start at 1

# %%
svc_results.to_csv('svc_results.csv', index_label='MoleculeId')

# %%
svc_results
# Out:
#       PredictedProbability
# 1                 0.859543
# 2                 0.869038
# 3                 0.184082
# 4                 0.833210
# 5                 0.189517
# 6                 0.276606
# 7                 0.859916
# 8                 0.706983
# 9                 0.798635
# 10                0.560328
# 11                0.396243
# 12                0.523807
# 13                0.802246
# 14                0.775395
# 15                0.482006
# 16                0.267614
# 17                0.266695
# 18                0.102292
# 19                0.363500
# 20                0.713610
# 21                0.151642
# 22                0.844944
# 23                0.479844
# 24                0.929077
# 25                0.952424
# 26                0.644193
# 27                0.314237
# 28                0.426872
# 29                0.147151
# 30                0.330916
# ...                    ...
# 2472              0.631377
# 2473              0.720921
# ...
